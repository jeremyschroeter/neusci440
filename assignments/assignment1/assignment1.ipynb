# %% [markdown]
# Assignment 1: Python, Numpy, and Matplotlib
# ----
# -----

# %% [markdown]
# Welcome to the first homework assignment! The way our homeworks will be structured is that we will ask you to implement a python function that does something specific. We will provide the structure of the function (keywords, inputs, etc) you just need to implement it. We have written functions for testing your work. If you haven't implemented the functions correctly then running the tests will throw an error. There are many ways to implement the functions, the test only checks that it gives the correct output. For functions that plot images we will check the PDF that you submit.
#
# The purpose of this assignment is mainly to dust off your coding skills and not to be super challenging. If you find yourself struggling or have any questions you can ask a classmate in the Discord server, come to office hours, or shoot me a message.
#
# Once you've passed all the tests and done everything we've asked you can export your notebook as a PDF and upload it to Canvas. If you don't know how to export I have written up a tutorial under the Pages tab on Canvas.

# %%
# You can ignore this cell
import test_functions
from utils import plot_slice

# %% [markdown]
# ## Section 1: Python

# %% [markdown]
# ### Problem 1
# The Pythagorean formula gives the length of the hypotenuse $c$ of a right triangle given the lengths of the two other sides $a$ and $b$
# $$
#     c = \sqrt{a^2 + b^2}
# $$
# Write a function to compute $c$ given any $a$ or $b$. **Hint:** you can take the square root of a number by raising it to the $\frac{1}{2}$

# %%
def pythagorean_formula(a: float, b: float) -> float:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s1_p1(pythagorean_formula)

# %% [markdown]
# ### Problem 2
# The mean/average $\mu$ of a list of numbers $\mathbf{x}$ is the sum of the list divided by the size of the list.
#
# $$
# \mathbf{x} = (x_1, x_2, \dots, x_n) \\
# \text{Avg}(x) = \mu = \frac{1}{n}\sum_{i=1}^n x_i
# $$
#
# Write a function to compute the mean of list of numbers.

# %%
def average(x: list[float]) -> float:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s1_p2(average)

# %% [markdown]
# ### Problem 3
# The variance of a list of numbers $\mathbf{x}$ is the average of the squared differences from the mean $\mu$. It is a measure of the spread of the data, how much it deviates from the average.
# $$
# \text{Var}(\mathbf{x}) = \text{Avg}((\mathbf{x} - \mu)^2)
# $$

# %% [markdown]
# Write a function to compute the variance of a list of numbers. Use the `average` function you implemented in the last problem. **Hint:** use a loop over the list to create a new list containing the squared differences

# %%
def variance(x: list[float]) -> float:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s1_p3(variance)

# %% [markdown]
# ### Problem 4
# Write a function that returns the largest element in a list of numbers. Don't use the built in `max` function. **Hint:** use `-inf` as your starting place for the largest number.

# %%
from math import inf
def largest(x: list[float]) -> float:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s1_p4(largest)

# %% [markdown]
# ## Section 2: Numpy

# %% [markdown]
# ### Problem 0
# Run the import statement below to import numpy

# %%
import numpy as np

# %% [markdown]
# ### Problem 1
# Write a function that generates a 1-dimensional array containing the integers ranging from $a$ to $b$.

# %%
def generate_int_arr(a: int, b: int) -> np.ndarray:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s2_p1(generate_int_arr)

# %% [markdown]
# ### Problem 2
# Write a function that takes as input a 3-dimensional array and returns the first 3 elements from the first axis, all the elements from the second axis, and the last two elements of the last axis.

# %%
def arr_slicing(arr: np.ndarray) -> np.ndarray:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s2_p2(arr_slicing)

# %% [markdown]
# ### Problem 3
# A Gaussian function has the general form
# $$
#     f(x) = e^{-x^2}
# $$
# Write a function that implements the Gaussian function

# %%
def gaussian(x: np.ndarray) -> np.ndarray:
    # Your code goes here
    return

# %% [markdown]
# Write a new Gaussian function that takes more parameters like so
# $$
#     f(x, a, b, c) = a\cdot e^{-(x - b)^2} + c
# $$

# %%
def pgaussian(x: np.ndarray, a: float, b: float, c: float) -> np.ndarray:
    # Your code goes here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s2_p3_1(gaussian)
test_functions.test_s2_p3_2(pgaussian)

# %% [markdown]
# ### Problem 4
# In neuroscience we often collect many samples of the system we are recording from after being presented with the same stimulus. For example, in the cockroach lab we could record 10 responses to 5 different sensory hair deflection angles (10 different recordings at each angle). If each recording is 1 second and recorded at 10kHz, then we would represent our data as an array of size (5, 10, 10000) (condition, recording, time). We could ask: *what is the ***average*** response of each stimulus condition*? To do this, we can take the average over the 10 different recordings. Our new array should be size (5, 10000) where now we only have the average of each condition.
#
# Write a function that takes in a 3-dimensional array of shape (5, 10, 10000) and performs the averaging described above (your function output should have a shape of (5, 10000)). Write a second function below that which calculates the standard deviation along the same axis. Use the built in `numpy` functions not the average and variance functions you wrote in the last section.

# %%
def average_data_matrix(data_matrix: np.ndarray) -> np.ndarray:
    # Your code here
    return

def std_data_matrix(data_matrix: np.ndarray)-> np.ndarray:
    # Your code here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s2_p4_1(average_data_matrix)
test_functions.test_s2_p4_2(std_data_matrix)

# %% [markdown]
# ### Problem 5
# We have written a helper function `plot_slice` which will highlight and plot the elements of a (5, 5) array obtained through indexing them. Run the cell below to see an example.

# %%
shape = (5, 5)
arr = np.arange(25).reshape(shape)

plot_slice(arr[:2, :2])

# %% [markdown]
# Change the input to `plot_slice` to reproduce the following images. **Hint:** You can use `::2` to get every-other element along an axis. <br>
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### Problem 6
# A very common use pattern when using numpy is to create an empty array (filled with zeros) and to then fill the columns or the rows sequentially with individual recordings. Write a function that generates an empty array of size (a, b) and then fills each row with a 1d array of random numbers (use `np.random.random(b)`)

# %%
def fill_arr(a: int, b: int) -> np.ndarray:
    # Your code here
    return

# %%
# Don't modify this cell, it is just for testing
test_functions.test_s2_p6(fill_arr)

# %% [markdown]
# ## Section 3: Matplotlib

# %% [markdown]
# ### Problem 0
# Run the cell below to import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 1
# Let's play with plotting some lines. Write a function that takes in values for $x$, $m$, and $b$, and returns the line defined by $y=mx+b$. Then write a function that takes the x-values and y-values and plots them. Please do some beautification to your plot, such as adding a title, axis labels, colors, etc. **Hint:** Use `np.linspace` to make your values for $x$

# %%
def line(x: np.ndarray, m: float, b: float) -> np.ndarray:
    # Your code here
    return


def plot_line(x_vals: np.ndarray, y_vals: np.ndarray) -> None:
    # Your code here
    # This function doesn't actually need to return anything, but it should plot the line
    return

plot_line()

# %% [markdown]
# ### Problem 2
# Do the same as before but plot a sine wave instead. Implement a function that will generate a sine wave with a certain frequency and amplitude. Recall that we can set the frequency and amplitude of a sine wave like so.
# $$
#     h(x, a, f) = a\sin(2\pi fx)
# $$
# Please do some beautification to your plot, such as adding a title, axis labels, colors etc.

# %%
def sine_wave(x: np.ndarray, a: float, f: float) -> np.ndarray:
    return a * np.sin(2 * np.pi * f * x)

def plot_sine_wave(x_vals: np.ndarray, y_vals: np.ndarray) -> None:
    # Your code here
    # This function doesn't actually need to return anything, but it should plot the line
    return

# %% [markdown]
# ### Problem 3
# Below we have provided a function that generates some normally distributed points in 2d. Write a function that takes the data and plots it as a scatter plot. Please do some beautification to your plot, such as adding a title, axis labels, etc.

# %%
def generate_2d_data():
    return np.random.multivariate_normal(mean=[6, 2], cov=[[3, 1], [1, 1]], size=1000)

def plot_2d_data(data: np.ndarray) -> None:
    # Your code here
    # This function doesn't actually need to return anything, but it should plot the data
    return

# %% [markdown]
# ### Problem 4
# Write a function that generates 4 increasingly large sets of numbers drawn from a standard normal distribution (mean 0, sd 1). Have the size of the datasets be increasing orders of magnitude starting at 10 (10, 100, 1000, 10000). Then write a different function that plots histograms of the 4 datasets next to one another. To do this you will need to use `plt.subplots` and `plt.hist`. Hint: to generate the data you can use the function `np.random.standard_normal`

# %%
def generate_datasets(dataset_sizes: list[int]) -> list[np.ndarray]:
    # Your code here
    return

def plot_datasets(datasets: list) -> None:
    # Your code here
    # This function doesn't actually need to return anything, but it should plot the datasets
    return

# %% [markdown]
# ### Problem 5
# Below we have provided a function that generates a dataset of 100 sinewaves with a controllable level of noise. Write a function that plots the mean of the sinewaves and also shades the region $\pm$ 1 standard deviation around the mean. You will need to use `plt.fillbetween`

# %%
def generate_noisy_sine_wave(noise: float) -> np.ndarray:
    x = np.linspace(0, 4 * np.pi, 1000)
    waves = np.zeros((100, 1000))
    for i in range(100):
        waves[i] = sine_wave(x, 1, 0.5).reshape(1, -1) + np.random.normal(0, noise, x.shape)
    return waves

def plot_noisy_sine_wave() -> None:
    # Your code here
    # This function doesn't actually need to return anything,
    # but it should plot the average of the sine wave 
    # and shade +- 1 std of the noisy sine waves
    return

# %%
noise_wave = generate_noisy_sine_wave(0.5)
avg = noise_wave.mean(0)
sd = noise_wave.std(0)
plt.plot(avg)
plt.fill_between(np.arange(1000), avg + sd, avg - sd, alpha=0.3)

# %% [markdown]
# ### Problem 6
# Write a function that uses the `generate_noisy_sine_wave` function to plot 4 versions of the plot you made above next to eachother, each with different levels of noise, and title each subplot with its corresponding noise level.

# %%
def plot_multiple_noisy_sine_waves() -> None:
    # Your code here
    # This function doesn't actually need to return anything,
    # but it should plot the average of the sine wave 
    # and shade +- 1 std of the noisy sine waves
    return
